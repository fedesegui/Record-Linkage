# %% [markdown]
# # Extracción y limpieza de datos
#
# El proceso demora aproximadamente 3 horas si se extraen ambas tablas.

# %%
import sys
from pathlib import Path

# ajustar al root del proyecto
ROOT = Path().resolve()  # si estás en notebooks/
sys.path.append(str(ROOT))

print(ROOT)
# Out:
# C:\Users\Feder\Documents\GitHub\Record-Linkage

# %%
import pandas as pd
import numpy as np
import os
os.chdir(r'C:\Users\Feder\Desktop\vinculacion_censo_rraa')

import sys
from pathlib import Path

ROOT = Path(r"C:\Users\Feder\Documents\GitHub\Record-Linkage")
sys.path.append(str(ROOT))

#from utils.vinculacion_deterministica.fucion_vinculacion import vincular_datasets
from data_sintetica.utils.saveFile import guardar_como_parquet

from data_sintetica.scripts.limpieza_de_datos import get_rraa_clean
rraa = get_rraa_clean(muestra = 10000000)
#guardar_como_parquet(rraa, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\rraa.parquet')
from data_sintetica.scripts.limpieza_de_datos import get_extranjeros_clean
#hub_personas_extranjeras = get_extranjeros_clean(muestra = 12000000)
#guardar_como_parquet(hub_personas_extranjeras, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\hub_personas.parquet')
from data_sintetica.scripts.limpieza_de_datos import get_censo_clean
censo = get_censo_clean(muestra = 3200000)
#guardar_como_parquet(censo, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\censo_new.parquet')
rraa = get_rraa_clean(muestra = 10000000)
#guardar_como_parquet(rraa, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\rraa.parquet')
from data_sintetica.scripts.limpieza_de_datos import get_extranjeros_clean
#hub_personas_extranjeras = get_extranjeros_clean(muestra = 12000000)
#guardar_como_parquet(hub_personas_extranjeras, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\hub_personas.parquet')
from data_sintetica.scripts.limpieza_de_datos import get_censo_clean
censo = get_censo_clean(muestra = 3200000)
#guardar_como_parquet(censo, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\censo_new.parquet')
# Out:
# limpieza_database
# Comenzo el proceso: 23:19:05
# Se cargo la tabla: 23:19:05
# limpieza_database
# Se limpio la tabla: 23:19:05
# Se modificaron los nombres y apellidos: 23:19:08
# Se modificaron las fechas de nacimiento: 23:19:08
# Se modificaron los documentos: 23:19:08
# limpieza_database
# Comenzo el proceso: 23:19:13
# Se cargo la tabla: 23:19:13
# limpieza_database
# Se limpio la tabla: 23:19:13
# Se modificaron los nombres y apellidos: 23:19:15
# Se modificaron las fechas de nacimiento: 23:19:15
# Se modificaron los documentos: 23:19:15

# %%
import pyarrow as pa

# from scripts.limpieza_de_datos import update_rraa_clean

# rraa_updated = update_rraa_clean(rraa)
rraa_updated = rraa

guardar_como_parquet(rraa_updated, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\rraa.parquet')
# Out:
# Se guardó el DataFrame como Parquet en: C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\rraa.parquet

# %%
guardar_como_parquet(censo, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\censo.parquet')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pyarrow as pa
# ----> 3 guardar_como_parquet(censo, r'C:\Users\Feder\Desktop\vinculacion_censo_rraaa\data\raw\censo.parquet')
#
# File ~\Documents\GitHub\Record-Linkage\data_sintetica\utils\saveFile.py:19, in guardar_como_parquet(df, ruta_archivo)
#      16     print(f"Se creó el directorio: {directorio}")
#      18 # Guardar el DataFrame como archivo Parquet
# ---> 19 df.to_parquet(ruta_archivo)
#      20 print(f"Se guardó el DataFrame como Parquet en: {ruta_archivo}")
#
# AttributeError: 'NoneType' object has no attribute 'to_parquet'
