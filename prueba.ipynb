# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Feder\Documents\GitHub\Record-Linkage\.venv311\Scripts\python.exe

# %%
import time
t0 = time.time()

import pandas as pd

print(time.time() - t0)
# Out:
# 0.0
